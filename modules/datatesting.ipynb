# %%
# setup
from scipy.io import loadmat
f = loadmat("../mat_files/CMIP5_historical_tasmax.mat")
f['results']['GCM'][0][0][0][34]
# Out:
# (array(['tasmax_day_ACCESS1-0_historical_r1i1p1_18500101-20051231.nc'],
#       dtype='<U59'), array([[42.5]]), array([[288.75]]), array([[107]], dtype=uint8), array([[155]], dtype=uint8), array([[281.30615234],
#        [283.99331665],
#        [281.38919067],
#        ...,
#        [276.88763428],
#        [279.58395386],
#        [278.75015259]]), array(['proleptic_gregorian'], dtype='<U19'), array(['K'], dtype='<U1'), array([[1850, 1850, 1850, ..., 2005, 2005, 2005]], dtype=uint16), array([[1850]], dtype=uint16), array([[2005]], dtype=uint16), array([[ 1,  1,  1, ..., 12, 12, 12]], dtype=uint8), array([[0]], dtype=uint8), array([[(array([[1.85000000e+03, 1.00000000e+00, 1.51835571e+01],
#        [1.85000000e+03, 2.00000000e+00, 1.57656189e+01],
#        [1.85000000e+03, 3.00000000e+00, 1.69607483e+01],
#        [1.85000000e+03, 4.00000000e+00, 2.17759033e+01],
#        [1.85000000e+03, 5.00000000e+00, 2.32821594e+01],
#        [1.85000000e+03, 6.00000000e+00, 2.82987000e+01],
# ...
